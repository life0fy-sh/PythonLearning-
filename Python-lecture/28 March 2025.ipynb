# %%
# Matplotlib in python 
# install matplatlib

# %pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 241.2 kB/s eta 0:00:32
#    -- ------------------------------------- 0.5/8.1 MB 241.2 kB/s eta 0:00:32
#    -- ------------------------------------- 0.5/8.1 MB 241.2 kB/s eta 0:00:32
#    -- ------------------------------------- 0.5/8.1 MB 241.2 kB/s eta 0:00:32
# ...
